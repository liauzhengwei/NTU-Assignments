# %%
sentence = """Mr. Sherwood said reaction to Sea Containers’ proposal has been "very positive." In
New York Stock Exchange composite trading yesterday, Sea Containers closed at
$62.625, up 62.5 cents."""

# %%
# Simple split by spaces
tokens = sentence.split()

for token in tokens:
  print(token)
# Out:
# Mr.
# Sherwood
# said
# reaction
# to
# Sea
# Containers’
# proposal
# has
# been
# "very
# positive."
# In
# New
# York
# Stock
# Exchange
# composite
# trading
# yesterday,
# Sea
# Containers
# closed
# at
# $62.625,
# up
# 62.5
# cents.

# %%
# Regex tokenisation (words only)
import re

tokens = re.findall(r"\w+",sentence)
for token in tokens:
  print(token)
# Out:
# Mr
# Sherwood
# said
# reaction
# to
# Sea
# Containers
# proposal
# has
# been
# very
# positive
# In
# New
# York
# Stock
# Exchange
# composite
# trading
# yesterday
# Sea
# Containers
# closed
# at
# 62
# 625
# up
# 62
# 5
# cents

# %%
# NLTK
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

tokens = word_tokenize(sentence)
for token in tokens:
  print(token)
# Out:
# Mr.
# Sherwood
# said
# reaction
# to
# Sea
# Containers
# ’
# proposal
# has
# been
# ``
# very
# positive
# .
# ''
# In
# New
# York
# Stock
# Exchange
# composite
# trading
# yesterday
# ,
# Sea
# Containers
# closed
# at
# $
# 62.625
# ,
# up
# 62.5
# cents
# .
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# spaCy
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp(sentence)
tokens = [token.text for token in doc]
for token in tokens:
  print(token)
# Out:
# Mr.
# Sherwood
# said
# reaction
# to
# Sea
# Containers
# ’
# proposal
# has
# been
# "
# very
# positive
# .
# "
# In
#
#
# New
# York
# Stock
# Exchange
# composite
# trading
# yesterday
# ,
# Sea
# Containers
# closed
# at
#
#
# $
# 62.625
# ,
# up
# 62.5
# cents
# .
