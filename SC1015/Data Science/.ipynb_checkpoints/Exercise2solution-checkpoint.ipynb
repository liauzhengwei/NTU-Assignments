# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(train.dtypes)
train.info()
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
# ...

# %%
inttrain = train.select_dtypes('int64')
inttrain
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %% [markdown]
# Actual Numeric Values:
# Id, LotArea, YrSold, YearBuilt, YearRemodAdd, BsmtFinSF1,BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, 1stFlrSF,2ndFlrSF, LowQualFinSF,GrLivArea, BsmtFullBath,BsmtHalfBath, FullBath,HalfBath,BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch,3SsnPorch, ScreenPorch, PoolArea, MiscVal, SalePrice
#
#
# Categorical Variables:
# MSSubClass, MoSold, OverallQual,OverallCond,

# %%
inttrainclean = inttrain.copy()

# %%
inttrainclean1 = inttrainclean.loc[:,inttrainclean.columns!='MoSold']
inttrainclean2 = inttrainclean1.loc[:,inttrainclean1.columns!='MSSubClass']
inttrainclean3 = inttrainclean2.loc[:,inttrainclean2.columns!='OverallQual']
inttrainclean4 = inttrainclean3.loc[:,inttrainclean3.columns!='OverallCond']

print(inttrainclean4)
# Out:
#         Id  LotArea  YearBuilt  YearRemodAdd  BsmtFinSF1  BsmtFinSF2  \
# 0        1     8450       2003          2003         706           0
# 1        2     9600       1976          1976         978           0
# 2        3    11250       2001          2002         486           0
# 3        4     9550       1915          1970         216           0
# 4        5    14260       2000          2000         655           0
# ...    ...      ...        ...           ...         ...         ...
# 1455  1456     7917       1999          2000           0           0
# 1456  1457    13175       1978          1988         790         163
# 1457  1458     9042       1941          2006         275           0
# 1458  1459     9717       1950          1996          49        1029
# 1459  1460     9937       1965          1965         830         290
#
#       BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# ...

# %%
SP= pd.DataFrame(inttrainclean4['SalePrice'])
SP.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = SP, orient = "h")

f=plt.figure(figsize=(12,6))
sb.histplot(data = SP)

f = plt.figure(figsize = (12,6))
sb.kdeplot(data = SP)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
LA = pd.DataFrame(inttrainclean4['LotArea'])
LA.describe()
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = LA, orient = "h")

f=plt.figure(figsize=(12,6))
sb.histplot(data = LA)

f = plt.figure(figsize = (12,6))
sb.kdeplot(data = LA)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
jointSPLA = pd.concat([SP,LA],axis =1)
jointSPLA
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# ...         ...      ...
# 1455     175000     7917
# 1456     210000    13175
# 1457     266500     9042
# 1458     142125     9717
# 1459     147500     9937
#
# [1460 rows x 2 columns]

# %%
sb.jointplot(data = jointSPLA,x = "LotArea",y="SalePrice",height = 12)

# %%
jointSPLA.corr()
# Out:
#            SalePrice   LotArea
# SalePrice   1.000000  0.263843
# LotArea     0.263843  1.000000

# %% [markdown]
# BONUS
