# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()
from scipy.stats import skew

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
LA = pd.DataFrame(train['LotArea'])
GLA = pd.DataFrame(train['GrLivArea'])
TBSF = pd.DataFrame(train['TotalBsmtSF'])
GA = pd.DataFrame(train['GarageArea'])

f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = LA,orient = "h")

f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = GLA,orient = "h")

f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = TBSF,orient = "h")

f,axes = plt.subplots(1,1, figsize = (12,6))
sb.boxplot(data = GA,orient = "h")
# Out:
# <AxesSubplot:>

# %%
Q1LA = LA.quantile(0.25)
Q3LA = LA.quantile(0.75)
IQRLA = Q3LA - Q1LA
((LA < (Q1LA-1.5*IQRLA))|(LA>(Q3LA+1.5*IQRLA))).sum()
# Out:
# LotArea    69
# dtype: int64

# %%
Q1TBSF = TBSF.quantile(0.25)
Q3TBSF = TBSF.quantile(0.75)
IQRTBSF = Q3TBSF - Q1TBSF
((TBSF < (Q1TBSF-1.5*IQRTBSF))|(TBSF>(Q3TBSF+1.5*IQRTBSF))).sum()
# Out:
# TotalBsmtSF    61
# dtype: int64

# %%
Q1GA = GA.quantile(0.25)
Q3GA = GA.quantile(0.75)
IQRGA = Q3GA - Q1GA
((GA < (Q1GA-1.5*IQRGA))|(GA>(Q3GA+1.5*IQRGA))).sum()
# Out:
# GarageArea    21
# dtype: int64

# %%
Q1GLA = GLA.quantile(0.25)
Q3GLA = GLA.quantile(0.75)
IQRGLA = Q3GLA - Q1GLA
((GLA < (Q1GLA-1.5*IQRGLA))|(GLA>(Q3GLA+1.5*IQRGLA))).sum()
# Out:
# GrLivArea    31
# dtype: int64

# %% [markdown]
# LotArea has the maximum number of outliers as per boxplot with 69 outliers.

# %%
LA.describe()
#difference in mean and median = 1038
# Out:
#              LotArea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
print(skew(LA))
# Out:
# [12.19514213]

# %%
GA.describe()
#difference in mean and median = -8.
# Out:
#         GarageArea
# count  1460.000000
# mean    472.980137
# std     213.804841
# min       0.000000
# 25%     334.500000
# 50%     480.000000
# 75%     576.000000
# max    1418.000000

# %%
print(skew(GA))
# Out:
# [0.17979594]

# %%
GLA.describe()
#difference in mean and median = 51
# Out:
#          GrLivArea
# count  1460.000000
# mean   1515.463699
# std     525.480383
# min     334.000000
# 25%    1129.500000
# 50%    1464.000000
# 75%    1776.750000
# max    5642.000000

# %%
print(skew(GLA))
# Out:
# [1.36515595]

# %%
TBSF.describe()
#difference in mean and median = 66
# Out:
#        TotalBsmtSF
# count  1460.000000
# mean   1057.429452
# std     438.705324
# min       0.000000
# 25%     795.750000
# 50%     991.500000
# 75%    1298.250000
# max    6110.000000

# %%
print(skew(TBSF))
# Out:
# [1.52268809]

# %% [markdown]
# LotArea is the most skewed variable from a regular normal distribution as compared to other variables, it has the greatest skew.The skew is positive as the mean is greater than the median.

# %%
SP = pd.DataFrame(train['SalePrice'])

# %%
jointSPLA = pd.concat([SP, LA], axis = 1)
jointSPLA.corr()
# Out:
#            SalePrice   LotArea
# SalePrice   1.000000  0.263843
# LotArea     0.263843  1.000000

# %%
jointSPGA = pd.concat([SP, GA], axis = 1)
jointSPGA.corr()
# Out:
#             SalePrice  GarageArea
# SalePrice    1.000000    0.623431
# GarageArea   0.623431    1.000000

# %%
jointSPGLA = pd.concat([SP, GLA], axis = 1)
jointSPGLA.corr()
# Out:
#            SalePrice  GrLivArea
# SalePrice   1.000000   0.708624
# GrLivArea   0.708624   1.000000

# %%
jointSPTBSF = pd.concat([SP, TBSF], axis = 1)
jointSPTBSF.corr()
# Out:
#              SalePrice  TotalBsmtSF
# SalePrice     1.000000     0.613581
# TotalBsmtSF   0.613581     1.000000

# %% [markdown]
# GrLivArea and GarageArea are the top two variables to predict SalePrice as they have the two highest correlation.

# %%
MS = pd.DataFrame(train['MSSubClass'])
N = pd.DataFrame(train['Neighborhood'])
BLT = pd.DataFrame(train['BldgType'])
OQ = pd.DataFrame(train['OverallQual'])

# %%
print("MSSubClass: ",len(train['MSSubClass'].dropna().unique()))
print("Neighborhood: ",len(train['Neighborhood'].dropna().unique()))
print("BldgType: ",len(train['BldgType'].dropna().unique()))
print("OverallQual: ",len(train['OverallQual'].dropna().unique()))
# Out:
# MSSubClass:  15
# Neighborhood:  25
# BldgType:  5
# OverallQual:  10

# %% [markdown]
# Neighborhood has the highest number of levels

# %%
print(train['MSSubClass'].value_counts())
print(train['Neighborhood'].value_counts())
print(train['BldgType'].value_counts())
print(train['OverallQual'].value_counts())
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %% [markdown]
# The level that has the highest number of houses for MSSubClass is 20 with 536 houses.
# The level that has the highest number of houses for Neighborhood is NAmes with 255 houses.
# The level that has the highest number of houses for BldgType is 1Fam with 1220 houses.
# The level that has the highest number of houses for Overall Qual is 5 with 397 houses.

# %%
avgMS = train.groupby('MSSubClass')['SalePrice'].median().sort_values().index
sb.boxplot(x = 'MSSubClass',y = 'SalePrice',data = train, order = avgMS)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
avgN = train.groupby('Neighborhood')['SalePrice'].median().sort_values().index
sb.boxplot(y = 'Neighborhood',x = 'SalePrice',data = train,order = avgN)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Neighborhood'>

# %%
avgBT = train.groupby('BldgType')['SalePrice'].median().sort_values().index
sb.boxplot(y = 'BldgType',x = 'SalePrice',data = train,order = avgBT)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='BldgType'>

# %%
avgOQ = train.groupby('OverallQual')['SalePrice'].median().sort_values().index
sb.boxplot(x = 'OverallQual',y = 'SalePrice',data = train,order = avgOQ)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# Overall Qual can be used to predict SalePrice as when Overall Qual increases, Mean SalePrice increases exponentially. Neighborhood can also be used due to it each neighborhood varying more in SalePrice than for each MSSubClass and each BldgType

# %%
#GarageCond--NA, Garage Qual--NA, GarageArea--0,GarageFinish--NA, 
#GarageYrBlt--NA, GarageType--NA,GarageCars--0

NOG = train.loc[train['GarageArea']==0]
NOG.info()
HG = train.loc[train['GarageArea']!=0]
HG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 39 to 1453
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             81 non-null     int64
#  1   MSSubClass     81 non-null     int64
#  2   MSZoning       81 non-null     object
#  3   LotFrontage    74 non-null     float64
#  4   LotArea        81 non-null     int64
#  5   Street         81 non-null     object
#  6   Alley          9 non-null      object
#  7   LotShape       81 non-null     object
#  8   LandContour    81 non-null     object
#  9   Utilities      81 non-null     object
#  10  LotConfig      81 non-null     object
#  11  LandSlope      81 non-null     object
#  12  Neighborhood   81 non-null     object
#  13  Condition1     81 non-null     object
#  14  Condition2     81 non-null     object
#  15  BldgType       81 non-null     object
#  16  HouseStyle     81 non-null     object
#  17  OverallQual    81 non-null     int64
#  18  OverallCond    81 non-null     int64
#  19  YearBuilt      81 non-null     int64
#  20  YearRemodAdd   81 non-null     int64
#  21  RoofStyle      81 non-null     object
#  22  RoofMatl       81 non-null     object
#  23  Exterior1st    81 non-null     object
#  24  Exterior2nd    81 non-null     object
#  25  MasVnrType     81 non-null     object
#  26  MasVnrArea     81 non-null     float64
#  27  ExterQual      81 non-null     object
#  28  ExterCond      81 non-null     object
#  29  Foundation     81 non-null     object
#  30  BsmtQual       74 non-null     object
#  31  BsmtCond       74 non-null     object
#  32  BsmtExposure   74 non-null     object
#  33  BsmtFinType1   74 non-null     object
#  34  BsmtFinSF1     81 non-null     int64
#  35  BsmtFinType2   74 non-null     object
#  36  BsmtFinSF2     81 non-null     int64
#  37  BsmtUnfSF      81 non-null     int64
#  38  TotalBsmtSF    81 non-null     int64
#  39  Heating        81 non-null     object
#  40  HeatingQC      81 non-null     object
#  41  CentralAir     81 non-null     object
#  42  Electrical     81 non-null     object
#  43  1stFlrSF       81 non-null     int64
#  44  2ndFlrSF       81 non-null     int64
#  45  LowQualFinSF   81 non-null     int64
#  46  GrLivArea      81 non-null     int64
#  47  BsmtFullBath   81 non-null     int64
#  48  BsmtHalfBath   81 non-null     int64
#  49  FullBath       81 non-null     int64
#  50  HalfBath       81 non-null     int64
#  51  BedroomAbvGr   81 non-null     int64
#  52  KitchenAbvGr   81 non-null     int64
#  53  KitchenQual    81 non-null     object
#  54  TotRmsAbvGrd   81 non-null     int64
#  55  Functional     81 non-null     object
#  56  Fireplaces     81 non-null     int64
#  57  FireplaceQu    9 non-null      object
#  58  GarageType     0 non-null      object
#  59  GarageYrBlt    0 non-null      float64
#  60  GarageFinish   0 non-null      object
#  61  GarageCars     81 non-null     int64
#  62  GarageArea     81 non-null     int64
#  63  GarageQual     0 non-null      object
#  64  GarageCond     0 non-null      object
#  65  PavedDrive     81 non-null     object
#  66  WoodDeckSF     81 non-null     int64
#  67  OpenPorchSF    81 non-null     int64
#  68  EnclosedPorch  81 non-null     int64
#  69  3SsnPorch      81 non-null     int64
#  70  ScreenPorch    81 non-null     int64
#  71  PoolArea       81 non-null     int64
#  72  PoolQC         0 non-null      object
#  73  Fence          16 non-null     object
#  74  MiscFeature    3 non-null      object
#  75  MiscVal        81 non-null     int64
#  76  MoSold         81 non-null     int64
#  77  YrSold         81 non-null     int64
#  78  SaleType       81 non-null     object
#  79  SaleCondition  81 non-null     object
#  80  SalePrice      81 non-null     int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 51.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1379 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1379 non-null   int64
#  1   MSSubClass     1379 non-null   int64
#  2   MSZoning       1379 non-null   object
#  3   LotFrontage    1127 non-null   float64
#  4   LotArea        1379 non-null   int64
#  5   Street         1379 non-null   object
#  6   Alley          82 non-null     object
#  7   LotShape       1379 non-null   object
#  8   LandContour    1379 non-null   object
#  9   Utilities      1379 non-null   object
#  10  LotConfig      1379 non-null   object
#  11  LandSlope      1379 non-null   object
#  12  Neighborhood   1379 non-null   object
#  13  Condition1     1379 non-null   object
#  14  Condition2     1379 non-null   object
#  15  BldgType       1379 non-null   object
#  16  HouseStyle     1379 non-null   object
#  17  OverallQual    1379 non-null   int64
#  18  OverallCond    1379 non-null   int64
#  19  YearBuilt      1379 non-null   int64
#  20  YearRemodAdd   1379 non-null   int64
#  21  RoofStyle      1379 non-null   object
#  22  RoofMatl       1379 non-null   object
#  23  Exterior1st    1379 non-null   object
#  24  Exterior2nd    1379 non-null   object
#  25  MasVnrType     1371 non-null   object
#  26  MasVnrArea     1371 non-null   float64
#  27  ExterQual      1379 non-null   object
#  28  ExterCond      1379 non-null   object
#  29  Foundation     1379 non-null   object
#  30  BsmtQual       1349 non-null   object
#  31  BsmtCond       1349 non-null   object
#  32  BsmtExposure   1348 non-null   object
#  33  BsmtFinType1   1349 non-null   object
#  34  BsmtFinSF1     1379 non-null   int64
#  35  BsmtFinType2   1348 non-null   object
#  36  BsmtFinSF2     1379 non-null   int64
#  37  BsmtUnfSF      1379 non-null   int64
#  38  TotalBsmtSF    1379 non-null   int64
#  39  Heating        1379 non-null   object
#  40  HeatingQC      1379 non-null   object
#  41  CentralAir     1379 non-null   object
#  42  Electrical     1378 non-null   object
#  43  1stFlrSF       1379 non-null   int64
#  44  2ndFlrSF       1379 non-null   int64
#  45  LowQualFinSF   1379 non-null   int64
#  46  GrLivArea      1379 non-null   int64
#  47  BsmtFullBath   1379 non-null   int64
#  48  BsmtHalfBath   1379 non-null   int64
#  49  FullBath       1379 non-null   int64
#  50  HalfBath       1379 non-null   int64
#  51  BedroomAbvGr   1379 non-null   int64
#  52  KitchenAbvGr   1379 non-null   int64
#  53  KitchenQual    1379 non-null   object
#  54  TotRmsAbvGrd   1379 non-null   int64
#  55  Functional     1379 non-null   object
#  56  Fireplaces     1379 non-null   int64
#  57  FireplaceQu    761 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1379 non-null   int64
#  62  GarageArea     1379 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1379 non-null   object
#  66  WoodDeckSF     1379 non-null   int64
#  67  OpenPorchSF    1379 non-null   int64
#  68  EnclosedPorch  1379 non-null   int64
#  69  3SsnPorch      1379 non-null   int64
#  70  ScreenPorch    1379 non-null   int64
#  71  PoolArea       1379 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          265 non-null    object
#  74  MiscFeature    51 non-null     object
#  75  MiscVal        1379 non-null   int64
#  76  MoSold         1379 non-null   int64
#  77  YrSold         1379 non-null   int64
#  78  SaleType       1379 non-null   object
#  79  SaleCondition  1379 non-null   object
#  80  SalePrice      1379 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 883.4+ KB

# %%
sb.boxplot(x = 'GarageArea',y = 'SalePrice',data = NOG)
NOG.describe()
# Out:
#                 Id  MSSubClass  LotFrontage       LotArea  OverallQual  \
# count    81.000000   81.000000    74.000000     81.000000    81.000000
# mean    707.012346   71.790123    60.405405   7469.679012     4.604938
# std     432.877104   58.327248    22.686620   3116.165893     1.136651
# min      40.000000   20.000000    21.000000   1491.000000     1.000000
# 25%     308.000000   30.000000    50.000000   5586.000000     4.000000
# 50%     639.000000   50.000000    60.000000   7711.000000     5.000000
# 75%    1097.000000   90.000000    69.250000   9098.000000     5.000000
# max    1454.000000  190.000000   153.000000  18030.000000     8.000000
#
#        OverallCond    YearBuilt  YearRemodAdd  MasVnrArea   BsmtFinSF1  ...  \
# count    81.000000    81.000000     81.000000   81.000000    81.000000  ...
# mean      5.530864  1942.481481   1975.172840   13.777778   240.382716  ...
# std       1.565938    29.664841     21.743844   52.372703   331.144552  ...
# min       1.000000  1872.000000   1950.000000    0.000000     0.000000  ...
# 25%       5.000000  1920.000000   1950.000000    0.000000     0.000000  ...
# 50%       5.000000  1940.000000   1971.000000    0.000000     0.000000  ...
# 75%       7.000000  1970.000000   1996.000000    0.000000   432.000000  ...
# max       9.000000  2007.000000   2008.000000  270.000000  1440.000000  ...
#
#        WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# count   81.000000    81.000000      81.000000       81.0         81.0
# mean    39.555556    36.172840      37.530864        0.0          0.0
# std     82.426179    81.820045      68.891234        0.0          0.0
# min      0.000000     0.000000       0.000000        0.0          0.0
# 25%      0.000000     0.000000       0.000000        0.0          0.0
# 50%      0.000000     0.000000       0.000000        0.0          0.0
# 75%     32.000000    30.000000      30.000000        0.0          0.0
# max    352.000000   523.000000     286.000000        0.0          0.0
#
#        PoolArea      MiscVal     MoSold       YrSold      SalePrice
# count      81.0    81.000000  81.000000    81.000000      81.000000
# mean        0.0    53.703704   6.111111  2007.876543  103317.283951
# std         0.0   393.365112   2.828427     1.297909   32815.023389
# min         0.0     0.000000   1.000000  2006.000000   34900.000000
# 25%         0.0     0.000000   4.000000  2007.000000   82500.000000
# 50%         0.0     0.000000   6.000000  2008.000000  100000.000000
# 75%         0.0     0.000000   8.000000  2009.000000  124000.000000
# max         0.0  3500.000000  12.000000  2010.000000  200500.000000
#
# [8 rows x 38 columns]

# %%
f = plt.figure(figsize=(250, 5))
sb.boxplot(x = 'GarageArea',y = 'SalePrice',data = HG)
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
HG.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1379.000000  1379.000000  1127.000000    1379.000000  1379.000000
# mean    731.879623    56.022480    70.683230   10695.812183     6.187092
# std     421.059059    41.026897    24.261598   10214.702133     1.345780
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     366.500000    20.000000    60.000000    7741.000000     5.000000
# 50%     734.000000    50.000000    70.000000    9591.000000     6.000000
# 75%    1094.500000    70.000000    80.000000   11708.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1379.000000  1379.000000   1379.000000  1371.000000  1379.000000  ...
# mean      5.577955  1972.958666   1985.435098   108.997082   455.578680  ...
# std       1.081031    29.379883     20.444852   184.545459   459.691379  ...
# min       2.000000  1880.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1955.000000   1968.000000     0.000000     0.000000  ...
# 50%       5.000000  1976.000000   1994.000000     0.000000   400.000000  ...
# 75%       6.000000  2001.000000   2004.000000   171.500000   732.000000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1379.000000  1379.000000    1379.000000  1379.000000  1379.000000
# mean     97.456853    47.276287      21.039159     3.609862    15.945613
# std     126.699192    65.210465      60.535107    30.154682    57.249593
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    27.000000       0.000000     0.000000     0.000000
# 75%     171.000000    69.500000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold     SalePrice
# count  1379.000000   1379.000000  1379.000000  1379.000000    1379.00000
# mean      2.920957     42.889050     6.334300  2007.812183  185479.51124
# std      41.335545    501.613931     2.696674     1.330221   79023.89060
# min       0.000000      0.000000     1.000000  2006.000000   35311.00000
# 25%       0.000000      0.000000     5.000000  2007.000000  134000.00000
# 50%       0.000000      0.000000     6.000000  2008.000000  167500.00000
# 75%       0.000000      0.000000     8.000000  2009.000000  217750.00000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.00000
#
# [8 rows x 38 columns]

# %% [markdown]
# Comparing mean and median values, it is clear that having a garage increases the SalePrice of the house.Mean SalePrice with and without garage is 185480 and 103317 respectively. Median SalePrice with and without garage is 167500 and 100000 respectively.
