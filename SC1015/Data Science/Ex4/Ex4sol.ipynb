# %%
import os
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

linreg = LinearRegression()

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
GLA = pd.DataFrame(train['GrLivArea'])
SP = pd.DataFrame(train['SalePrice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(GLA, SP, test_size = 0.25)

# %%
linreg.fit(X_train, y_train)

print('Intercept of Regression \t: b = ',linreg.intercept_)
print('Coefficients of Regression \t: a = ',linreg.coef_)
print()

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
# Out:
# Intercept of Regression 	: b =  [11742.13937024]
# Coefficients of Regression 	: a =  [[112.0379269]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5260342676739543
# Mean Squared Error (MSE) 	: 3109542951.4917254
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.4122167077550697
# Mean Squared Error (MSE) 	: 3258817365.513625
# Text(0, 0.5, 'Predicted values of the Response Variable (Test)')

# %%
GA = pd.DataFrame(train['GarageArea'])
TBSF = pd.DataFrame(train['TotalBsmtSF'])

# %%
X_train, X_test, y_train, y_test = train_test_split(GA, SP, test_size = 0.25)

linreg.fit(X_train, y_train)

print('Intercept of Regression \t: b = ',linreg.intercept_)
print('Coefficients of Regression \t: a = ',linreg.coef_)
print()

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
# Out:
# Intercept of Regression 	: b =  [69173.83903384]
# Coefficients of Regression 	: a =  [[240.34106435]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3955635937472157
# Mean Squared Error (MSE) 	: 4119191275.132629
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.33921809219635934
# Mean Squared Error (MSE) 	: 3093327313.322079
# Text(0, 0.5, 'Predicted values of the Response Variable (Test)')

# %%
X_train, X_test, y_train, y_test = train_test_split(TBSF, SP, test_size = 0.25)

linreg.fit(X_train, y_train)

print('Intercept of Regression \t: b = ',linreg.intercept_)
print('Coefficients of Regression \t: a = ',linreg.coef_)
print()

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
# Out:
# Intercept of Regression 	: b =  [67664.32100459]
# Coefficients of Regression 	: a =  [[106.30615435]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.35684169321604076
# Mean Squared Error (MSE) 	: 4030285585.5864253
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.43070496473271014
# Mean Squared Error (MSE) 	: 3659361873.0914598
# Text(0, 0.5, 'Predicted values of the Response Variable (Test)')

# %% [markdown]
# GrLivArea VS SalePrice is the best model as the test data has the highest explained variance among the three and the lowest mean squared error.

# %%
Q1GLA = GLA.quantile(0.25)
Q3GLA = GLA.quantile(0.75)
IQRGLA = Q3GLA - Q1GLA
UHGLA = Q3GLA + 1.5*IQRGLA
LHGLA = Q1GLA - 1.5*IQRGLA
((GLA < LHGLA)|(GLA > UHGLA)).sum()
# Out:
# GrLivArea    31
# dtype: int64

# %%
f, axes = plt.subplots(1,1,figsize=(24,4)) 
sb.boxplot(data=GLA, orient = "h")
# Out:
# <AxesSubplot:>

# %%
print("Old Shape: ", train.shape)
upperGLA = np.where(GLA < LHGLA)
lowerGLA = np.where(GLA > UHGLA)
# Out:
# Old Shape:  (1460, 81)

# %%
train.drop(lowerGLA[0], inplace = True)
train.drop(upperGLA[0], inplace = True)
print("New Shape: ", train.shape)
# Out:
# New Shape:  (1429, 81)

# %%
#repeat for SalePrice #do the test and train thing

# %%
Q1SP = SP.quantile(0.25)
Q3SP = SP.quantile(0.75)
IQRSP = Q3SP - Q1SP
UHSP = Q3SP + 1.5*IQRSP
LHSP = Q1SP - 1.5*IQRSP
((SP < LHSP)|(SP > UHSP)).sum()
# Out:
# SalePrice    61
# dtype: int64

# %%
f, axes = plt.subplots(1,1,figsize=(24,4)) 
sb.boxplot(data=SP, orient = "h")
# Out:
# <AxesSubplot:>

# %%
print("Old Shape: ", train.shape)
upperSP = np.where(SP < LHSP)
lowerSP = np.where(SP > UHSP)
# Out:
# Old Shape:  (1429, 81)

# %%
train.drop(lowerSP[0], inplace = True,errors='ignore')
train.drop(upperSP[0], inplace = True)
print("New Shape: ", train.shape)
# Out:
# New Shape:  (1383, 81)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1383 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1383 non-null   int64
#  1   MSSubClass     1383 non-null   int64
#  2   MSZoning       1383 non-null   object
#  3   LotFrontage    1130 non-null   float64
#  4   LotArea        1383 non-null   int64
#  5   Street         1383 non-null   object
#  6   Alley          89 non-null     object
#  7   LotShape       1383 non-null   object
#  8   LandContour    1383 non-null   object
#  9   Utilities      1383 non-null   object
#  10  LotConfig      1383 non-null   object
#  11  LandSlope      1383 non-null   object
#  12  Neighborhood   1383 non-null   object
#  13  Condition1     1383 non-null   object
#  14  Condition2     1383 non-null   object
#  15  BldgType       1383 non-null   object
#  16  HouseStyle     1383 non-null   object
# ...

# %%
ga = pd.DataFrame(train['GrLivArea'])
sp = pd.DataFrame(train['SalePrice'])
sp.info()
ga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1383 entries, 0 to 1459
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SalePrice  1383 non-null   int64
# dtypes: int64(1)
# memory usage: 21.6 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1383 entries, 0 to 1459
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GrLivArea  1383 non-null   int64
# dtypes: int64(1)
# memory usage: 21.6 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(ga, sp, test_size = 0.25)

linreg.fit(X_train, y_train)

print('Intercept of Regression \t: b = ',linreg.intercept_)
print('Coefficients of Regression \t: a = ',linreg.coef_)
print()

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
# Out:
# Intercept of Regression 	: b =  [32249.53927925]
# Coefficients of Regression 	: a =  [[94.44974063]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.49168864526732203
# Mean Squared Error (MSE) 	: 1756550654.207832
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.43306031355769226
# Mean Squared Error (MSE) 	: 1929163377.5569782
# Text(0, 0.5, 'Predicted values of the Response Variable (Test)')

# %% [markdown]
# This model has a lower R^2 and MSE, indicating that this model is better with better prediction accuracy and goodness of fit.
